# %% [markdown]
# **STOCK PRICE PREDICTION USING LSTM**
#
#
# **Task 1: Stock Prediction**: In this enthralling task, I dive deep into the world of stock market forecasting. Armed with a comprehensive dataset of **Google's** historical stock prices and attributes, the challenge begins. Guided by the power of Long Short-Term Memory networks (LSTM), I embark on an 8-step journey:
#
# **Data Exploration**: Delving into 14 insightful columns and 1257 rows, understanding attributes like close, high, low, open, volume, and more.
#
# **Data Preprocessing**: From handling missing values to scaling data using MinMaxScaler, ensuring the dataset is primed for analysis.
#
# **LSTM Dataset Creation**: Crafting sequences of data for LSTM, a pivotal step towards accurate predictions.
#
# **Model Building**: Constructing a robust LSTM model using layers like LSTM, Dropout, and Dense, tuned to predict stock prices effectively.
#
# Training the Model: Iterating over the dataset 100 times, training the LSTM model to grasp intricate patterns.
#
# **Evaluation and Visualization**: Assessing the model's accuracy using metrics like Root Mean Squared Error (RMSE) and visualizing predicted prices against actual data for validation.
#
# **Future Predictions**: Peering into the future, predicting the next 30 days' open and close stock prices.
#
# **Upcoming Price Visualization**: Showcasing the upcoming stock price predictions, bridging the gap between data science and real-world applications.
#
#
# The dataset: https://www.kaggle.com/datasets/shreenidhihipparagi/google-stock-prediction?resource=download

# %% [markdown]
# **STEP 1 - Data Loading and Inspection**

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('GOOG.csv') # data_importing
df.head(20) # fetching first 20 rows of dataset
# Out:
#    symbol                       date   close      high       low    open  \
# 0    GOOG  2016-06-14 00:00:00+00:00  718.27  722.4700  713.1200  716.48
# 1    GOOG  2016-06-15 00:00:00+00:00  718.92  722.9800  717.3100  719.00
# 2    GOOG  2016-06-16 00:00:00+00:00  710.36  716.6500  703.2600  714.91
# 3    GOOG  2016-06-17 00:00:00+00:00  691.72  708.8200  688.4515  708.65
# 4    GOOG  2016-06-20 00:00:00+00:00  693.71  702.4800  693.4100  698.77
# 5    GOOG  2016-06-21 00:00:00+00:00  695.94  702.7700  692.0100  698.40
# 6    GOOG  2016-06-22 00:00:00+00:00  697.46  700.8600  693.0819  699.06
# 7    GOOG  2016-06-23 00:00:00+00:00  701.87  701.9500  687.0000  697.45
# 8    GOOG  2016-06-24 00:00:00+00:00  675.22  689.4000  673.4500  675.17
# 9    GOOG  2016-06-27 00:00:00+00:00  668.26  672.3000  663.2840  671.00
# 10   GOOG  2016-06-28 00:00:00+00:00  680.04  680.3300  673.0000  678.97
# 11   GOOG  2016-06-29 00:00:00+00:00  684.11  687.4292  681.4100  683.00
# 12   GOOG  2016-06-30 00:00:00+00:00  692.10  692.3200  683.6500  685.47
# 13   GOOG  2016-07-01 00:00:00+00:00  699.21  700.6500  692.1301  692.20
# 14   GOOG  2016-07-05 00:00:00+00:00  694.49  696.9400  688.8800  696.06
# 15   GOOG  2016-07-06 00:00:00+00:00  697.77  701.6800  689.0900  689.98
# 16   GOOG  2016-07-07 00:00:00+00:00  695.36  698.2000  688.2150  698.08
# 17   GOOG  2016-07-08 00:00:00+00:00  705.63  705.7100  696.4350  699.50
# 18   GOOG  2016-07-11 00:00:00+00:00  715.09  716.5100  707.2400  708.05
# 19   GOOG  2016-07-12 00:00:00+00:00  720.64  722.9400  715.9100  719.12
#
#      volume  adjClose   adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0   1306065    718.27  722.4700  713.1200   716.48    1306065      0.0
# 1   1214517    718.92  722.9800  717.3100   719.00    1214517      0.0
# 2   1982471    710.36  716.6500  703.2600   714.91    1982471      0.0
# 3   3402357    691.72  708.8200  688.4515   708.65    3402357      0.0
# 4   2082538    693.71  702.4800  693.4100   698.77    2082538      0.0
# 5   1465634    695.94  702.7700  692.0100   698.40    1465634      0.0
# 6   1184318    697.46  700.8600  693.0819   699.06    1184318      0.0
# 7   2171415    701.87  701.9500  687.0000   697.45    2171415      0.0
# 8   4449022    675.22  689.4000  673.4500   675.17    4449022      0.0
# 9   2641085    668.26  672.3000  663.2840   671.00    2641085      0.0
# 10  2173762    680.04  680.3300  673.0000   678.97    2173762      0.0
# 11  1932561    684.11  687.4292  681.4100   683.00    1932561      0.0
# 12  1597714    692.10  692.3200  683.6500   685.47    1597714      0.0
# 13  1344710    699.21  700.6500  692.1301   692.20    1344710      0.0
# 14  1462616    694.49  696.9400  688.8800   696.06    1462616      0.0
# 15  1411925    697.77  701.6800  689.0900   689.98    1411925      0.0
# 16  1304200    695.36  698.2000  688.2150   698.08    1304200      0.0
# 17  1575166    705.63  705.7100  696.4350   699.50    1575166      0.0
# 18  1111762    715.09  716.5100  707.2400   708.05    1111762      0.0
# 19  1336921    720.64  722.9400  715.9100   719.12    1336921      0.0
#
#     splitFactor
# 0           1.0
# 1           1.0
# 2           1.0
# 3           1.0
# 4           1.0
# 5           1.0
# 6           1.0
# 7           1.0
# 8           1.0
# 9           1.0
# 10          1.0
# 11          1.0
# 12          1.0
# 13          1.0
# 14          1.0
# 15          1.0
# 16          1.0
# 17          1.0
# 18          1.0
# 19          1.0

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# **STEP 2 - Data Preprocessing**

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(20)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26
# 2016-06-28  678.97  680.04
# 2016-06-29  683.00  684.11
# 2016-06-30  685.47  692.10
# 2016-07-01  692.20  699.21
# 2016-07-05  696.06  694.49
# 2016-07-06  689.98  697.77
# 2016-07-07  698.08  695.36
# 2016-07-08  699.50  705.63
# 2016-07-11  708.05  715.09
# 2016-07-12  719.12  720.64

# %% [markdown]
# **STEP 3 - Data Visualization**

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(20)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000
# 2016-06-28  0.004299  0.006356
# 2016-06-29  0.006473  0.008552
# 2016-06-30  0.007805  0.012863
# 2016-07-01  0.011435  0.016700
# 2016-07-05  0.013517  0.014153
# 2016-07-06  0.010238  0.015923
# 2016-07-07  0.014607  0.014622
# 2016-07-08  0.015373  0.020164
# 2016-07-11  0.019985  0.025268
# 2016-07-12  0.025956  0.028262

# %% [markdown]
# **STEP 4 - Data Splitting and Sequencing**

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# **STEP 5 - Model Building and Training**

# %%
# imported Sequential from keras.models
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50, 50)         │        10,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │           102 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,902 (120.71 KB)
#  Trainable params: 30,902 (120.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 9s 75ms/step - loss: 0.0267 - mean_absolute_error: 0.1217 - val_loss: 0.0249 - val_mean_absolute_error: 0.1365
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 0.0012 - mean_absolute_error: 0.0285 - val_loss: 0.0045 - val_mean_absolute_error: 0.0514
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 5.1330e-04 - mean_absolute_error: 0.0174 - val_loss: 0.0030 - val_mean_absolute_error: 0.0424
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 4.2913e-04 - mean_absolute_error: 0.0151 - val_loss: 0.0044 - val_mean_absolute_error: 0.0531
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.8889e-04 - mean_absolute_error: 0.0147 - val_loss: 0.0034 - val_mean_absolute_error: 0.0451
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 4.6420e-04 - mean_absolute_error: 0.0158 - val_loss: 0.0031 - val_mean_absolute_error: 0.0423
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 4.2467e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0039 - val_mean_absolute_error: 0.0483
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 3.6393e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0032 - val_mean_absolute_error: 0.0432
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.9182e-04 - mean_absolute_error: 0.0145 - val_loss: 0.0041 - val_mean_absolute_error: 0.0505
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 3.8929e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0034 - val_mean_absolute_error: 0.0446
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 3.5330e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0035 - val_mean_absolute_error: 0.0456
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 3.5181e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0034 - val_mean_absolute_error: 0.0445
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 3.4358e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0033 - val_mean_absolute_error: 0.0441
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 3.4702e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0038 - val_mean_absolute_error: 0.0475
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.1543e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0064 - val_mean_absolute_error: 0.0653
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 3.6849e-04 - mean_absolute_error: 0.0144 - val_loss: 0.0032 - val_mean_absolute_error: 0.0428
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 3.4966e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0038 - val_mean_absolute_error: 0.0478
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step - loss: 3.6257e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0048 - val_mean_absolute_error: 0.0547
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 3.0145e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0046 - val_mean_absolute_error: 0.0537
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 3.0368e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0043 - val_mean_absolute_error: 0.0511
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 2.8490e-04 - mean_absolute_error: 0.0124 - val_loss: 0.0054 - val_mean_absolute_error: 0.0582
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 2.9530e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0043 - val_mean_absolute_error: 0.0513
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 2.8984e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0041 - val_mean_absolute_error: 0.0496
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step - loss: 3.0561e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0047 - val_mean_absolute_error: 0.0534
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.8580e-04 - mean_absolute_error: 0.0123 - val_loss: 0.0066 - val_mean_absolute_error: 0.0667
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 3.3395e-04 - mean_absolute_error: 0.0132 - val_loss: 0.0051 - val_mean_absolute_error: 0.0560
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.7046e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0058 - val_mean_absolute_error: 0.0604
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.6882e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0050 - val_mean_absolute_error: 0.0547
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - loss: 2.8255e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0069 - val_mean_absolute_error: 0.0675
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step - loss: 2.9157e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0034 - val_mean_absolute_error: 0.0446
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.3968e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0018 - val_mean_absolute_error: 0.0312
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 3.0091e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0022 - val_mean_absolute_error: 0.0350
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.9171e-04 - mean_absolute_error: 0.0122 - val_loss: 0.0027 - val_mean_absolute_error: 0.0388
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.9060e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0032 - val_mean_absolute_error: 0.0441
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.6294e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0044 - val_mean_absolute_error: 0.0532
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.4516e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0028 - val_mean_absolute_error: 0.0396
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 2.5287e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0038 - val_mean_absolute_error: 0.0483
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 2.4398e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0045 - val_mean_absolute_error: 0.0523
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.3299e-04 - mean_absolute_error: 0.0115 - val_loss: 0.0083 - val_mean_absolute_error: 0.0765
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 2.4804e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0017 - val_mean_absolute_error: 0.0302
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.5084e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0028 - val_mean_absolute_error: 0.0405
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.4637e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0036 - val_mean_absolute_error: 0.0457
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 2.5503e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0027 - val_mean_absolute_error: 0.0391
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 131ms/step - loss: 2.3294e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0022 - val_mean_absolute_error: 0.0346
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 2.2610e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0029 - val_mean_absolute_error: 0.0406
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 2.3098e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0055 - val_mean_absolute_error: 0.0616
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 2.3210e-04 - mean_absolute_error: 0.0113 - val_loss: 0.0030 - val_mean_absolute_error: 0.0415
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 1.8410e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0034 - val_mean_absolute_error: 0.0449
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 2.3237e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0041 - val_mean_absolute_error: 0.0521
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.1489e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0031 - val_mean_absolute_error: 0.0434
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.0458e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0033 - val_mean_absolute_error: 0.0452
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 2.1542e-04 - mean_absolute_error: 0.0111 - val_loss: 0.0020 - val_mean_absolute_error: 0.0329
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 1.8170e-04 - mean_absolute_error: 0.0097 - val_loss: 0.0026 - val_mean_absolute_error: 0.0400
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - loss: 1.9979e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0023 - val_mean_absolute_error: 0.0361
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 1.5886e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0030 - val_mean_absolute_error: 0.0433
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.1161e-04 - mean_absolute_error: 0.0106 - val_loss: 0.0022 - val_mean_absolute_error: 0.0351
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - loss: 2.0191e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0018 - val_mean_absolute_error: 0.0310
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.9489e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0031 - val_mean_absolute_error: 0.0453
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.9353e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0015 - val_mean_absolute_error: 0.0284
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 69ms/step - loss: 1.9483e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0031 - val_mean_absolute_error: 0.0444
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.5330e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0018 - val_mean_absolute_error: 0.0316
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 1.6873e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0024 - val_mean_absolute_error: 0.0393
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 1.6651e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step - loss: 1.8316e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0044 - val_mean_absolute_error: 0.0557
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 60ms/step - loss: 1.7280e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0020 - val_mean_absolute_error: 0.0345
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.6186e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0016 - val_mean_absolute_error: 0.0296
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.6548e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.5266e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0018 - val_mean_absolute_error: 0.0312
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.4789e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0039 - val_mean_absolute_error: 0.0522
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.8699e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0027 - val_mean_absolute_error: 0.0421
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 1.5107e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0026 - val_mean_absolute_error: 0.0407
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 1.6550e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0023 - val_mean_absolute_error: 0.0377
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 1.6079e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0023 - val_mean_absolute_error: 0.0366
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - loss: 1.5954e-04 - mean_absolute_error: 0.0090 - val_loss: 0.0013 - val_mean_absolute_error: 0.0261
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step - loss: 1.6483e-04 - mean_absolute_error: 0.0092 - val_loss: 9.2973e-04 - val_mean_absolute_error: 0.0222
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.5897e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0027 - val_mean_absolute_error: 0.0407
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step - loss: 1.4857e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0020 - val_mean_absolute_error: 0.0351
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - loss: 1.4449e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0019 - val_mean_absolute_error: 0.0334
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.6080e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0033 - val_mean_absolute_error: 0.0487
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.7716e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0019 - val_mean_absolute_error: 0.0342
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 1.3519e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0023 - val_mean_absolute_error: 0.0386
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 1.4716e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0014 - val_mean_absolute_error: 0.0297
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step - loss: 1.2635e-04 - mean_absolute_error: 0.0081 - val_loss: 8.9246e-04 - val_mean_absolute_error: 0.0221
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 1.4492e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0013 - val_mean_absolute_error: 0.0260
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.3552e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0022 - val_mean_absolute_error: 0.0363
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 1.2198e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0023 - val_mean_absolute_error: 0.0371
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - loss: 1.6329e-04 - mean_absolute_error: 0.0092 - val_loss: 0.0030 - val_mean_absolute_error: 0.0461
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 1.2756e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0014 - val_mean_absolute_error: 0.0283
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 1.3034e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0013 - val_mean_absolute_error: 0.0271
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 5s 82ms/step - loss: 1.1497e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0023 - val_mean_absolute_error: 0.0389
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 88ms/step - loss: 1.1350e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0025 - val_mean_absolute_error: 0.0397
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 1.2224e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0022 - val_mean_absolute_error: 0.0373
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - loss: 1.3914e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0014 - val_mean_absolute_error: 0.0284
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 1.1094e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0021 - val_mean_absolute_error: 0.0359
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step - loss: 1.3124e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - loss: 1.4958e-04 - mean_absolute_error: 0.0088 - val_loss: 6.5739e-04 - val_mean_absolute_error: 0.0188
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 1.0281e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0021 - val_mean_absolute_error: 0.0376
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - loss: 1.2802e-04 - mean_absolute_error: 0.0081 - val_loss: 9.4157e-04 - val_mean_absolute_error: 0.0228
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 1.1593e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0010 - val_mean_absolute_error: 0.0243
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - loss: 1.1416e-04 - mean_absolute_error: 0.0075 - val_loss: 0.0011 - val_mean_absolute_error: 0.0250

# %% [markdown]
# **STEP 6 - Predictions and Visualization**

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
# array([[0.40511578, 0.4065032 ],
#        [0.4049187 , 0.40679008],
#        [0.40142715, 0.4037112 ],
#        [0.40396357, 0.40580612],
#        [0.40713835, 0.408571  ]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1422.0522, 1421.6487],
#        [1421.6869, 1422.1804],
#        [1415.2139, 1416.4741],
#        [1419.9161, 1420.3568],
#        [1425.8019, 1425.4811]], dtype=float32)

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1422.052246      1421.648682
# 2020-05-28  1396.86  1416.73     1421.686890      1422.180420
# 2020-05-29  1416.94  1428.92     1415.213867      1416.474121
# 2020-06-01  1418.39  1431.82     1419.916138      1420.356812
# 2020-06-02  1430.55  1439.22     1425.801880      1425.481079

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# **STEP 7 - Upcoming Price Prediction**

# %%
# df_merge = pd.read_csv('Google Stocks.csv')

# Creating a new DataFrame to append 10 days of empty data
new_data = pd.DataFrame(index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D'))

# Appending the new_data to df_merge
df_merge = pd.concat([df_merge, new_data])

# Now you can select the specific date range
selected_date_range = df_merge['2021-06-09':'2021-06-28']
print(selected_date_range)
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2396.306885      2367.165527
# 2021-06-10  2494.01  2521.60     2407.945312      2380.384521
# 2021-06-11  2524.92  2513.93     2423.913818      2396.143066
# 2021-06-11      NaN      NaN             NaN              NaN
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN
# 2021-06-17      NaN      NaN             NaN              NaN
# 2021-06-18      NaN      NaN             NaN              NaN
# 2021-06-19      NaN      NaN             NaN              NaN
# 2021-06-20      NaN      NaN             NaN              NaN
# 2021-06-21      NaN      NaN             NaN              NaN

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-03-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-03-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %%
# Define actual stock prices (replace [...] with your actual data)
actual_prices = np.array([100, 105, 110, 115, 120, 125])  # Example actual prices

# Define predicted stock prices (replace [...] with your predicted data)
predictions = np.array([98, 102, 108, 114, 118, 123])  # Example predicted prices

# Plotting the actual and predicted prices
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual Prices', color='blue')
plt.plot(predictions, label='Predicted Prices', color='red')
plt.xlabel('Time Steps')
plt.ylabel('Stock Price')
plt.title('Stock Price Prediction')
plt.legend()
plt.show()

# %%
# Data Preprocessing
# Handle missing values if needed
# Scale the data using MinMaxScaler

# Assuming 'close' column contains the stock prices
close_prices = df['close'].values.reshape(-1, 1)  # Reshape for MinMaxScaler

# Perform Min-Max scaling
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
close_prices_scaled = scaler.fit_transform(close_prices)

# %%
# Load the dataset (assuming the data variable contains the loaded dataset)
close_prices = df['close'].values.reshape(-1, 1)  # Assuming 'close' column contains the stock prices
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_close_prices = scaler.fit_transform(close_prices)

# %%
def create_lstm_dataset(data, time_steps=1):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:(i + time_steps), 0])
        y.append(data[i + time_steps, 0])
    return np.array(X), np.array(y)

# Create LSTM dataset
X, y = create_lstm_dataset(scaled_close_prices, time_steps=10)  # Assuming time_steps is 10

# %%
# Train-Test Split
split_ratio = 0.8  # 80% for training, 20% for testing

split_index = int(len(X) * split_ratio)
X_train, X_test, y_train, y_test = X[:split_index], X[split_index:], y[:split_index], y[split_index:]

# %%
# Build LSTM Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1], 1)))
model.add(LSTM(units=50))
model.add(Dense(units=1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Define the number of epochs and batch size
epochs = 50  # You can adjust this based on your preference
batch_size = 32  # You can adjust this based on your preference

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])

# Train the LSTM model
history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size)

# Plot training loss
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss', color='blue')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# Plot training accuracy
plt.figure(figsize=(12, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy', color='green')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.0000e+00 - loss: 0.0166
# Epoch 2/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.0000e+00 - loss: 0.0010
# Epoch 3/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 3.5069e-04
# Epoch 4/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 3.0884e-04
# Epoch 5/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 4.1721e-04
# Epoch 6/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 3.4754e-04
# Epoch 7/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 3.6654e-04
# Epoch 8/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 2.7947e-04
# Epoch 9/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 3.9143e-04
# Epoch 10/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 3.7279e-04
# Epoch 11/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 3.3870e-04
# Epoch 12/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 3.0809e-04
# Epoch 13/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 3.7872e-04
# Epoch 14/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 3.5310e-04
# Epoch 15/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.0000e+00 - loss: 3.5184e-04
# Epoch 16/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0000e+00 - loss: 2.5358e-04
# Epoch 17/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.0000e+00 - loss: 3.0275e-04
# Epoch 18/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0000e+00 - loss: 3.6582e-04
# Epoch 19/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 2.8174e-04
# Epoch 20/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 2.6142e-04
# Epoch 21/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.0000e+00 - loss: 2.7914e-04
# Epoch 22/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 3.1391e-04
# Epoch 23/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.0000e+00 - loss: 3.2245e-04
# Epoch 24/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 3.1466e-04
# Epoch 25/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 2.4665e-04
# Epoch 26/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 3.2231e-04
# Epoch 27/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 2.9515e-04
# Epoch 28/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 2.3870e-04
# Epoch 29/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.0000e+00 - loss: 2.5493e-04
# Epoch 30/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 2.3632e-04
# Epoch 31/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0000e+00 - loss: 2.1132e-04
# Epoch 32/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.0000e+00 - loss: 1.9769e-04
# Epoch 33/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 2.3385e-04
# Epoch 34/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0000e+00 - loss: 1.9477e-04
# Epoch 35/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.0000e+00 - loss: 2.7702e-04
# Epoch 36/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.0000e+00 - loss: 1.8340e-04
# Epoch 37/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.0000e+00 - loss: 1.8490e-04
# Epoch 38/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 2.4334e-04
# Epoch 39/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.0000e+00 - loss: 1.9704e-04
# Epoch 40/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 1.7020e-04
# Epoch 41/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 1.7305e-04
# Epoch 42/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.0000e+00 - loss: 2.0478e-04
# Epoch 43/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.0000e+00 - loss: 1.6586e-04
# Epoch 44/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 1.6526e-04
# Epoch 45/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 1.5872e-04
# Epoch 46/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.0000e+00 - loss: 1.6476e-04
# Epoch 47/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.0000e+00 - loss: 1.5205e-04
# Epoch 48/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.0000e+00 - loss: 1.6226e-04
# Epoch 49/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.0000e+00 - loss: 1.6105e-04
# Epoch 50/50
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.0000e+00 - loss: 1.9042e-04

# %% [markdown]
# **STEP 8 - Model Evaluation and Visualization**

# %%
# Evaluate the model
predicted_prices = model.predict(X_test)
predicted_prices = scaler.inverse_transform(predicted_prices)  # Inverse transform the predictions

# Assuming y_test contains the actual stock prices for the test data
from sklearn.metrics import mean_squared_error

# Calculate RMSE
rmse = np.sqrt(mean_squared_error(y_test, predicted_prices))
print('Root Mean Squared Error (RMSE):', rmse)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step
# Root Mean Squared Error (RMSE): 0.05248295921921749

# %%
predictions = model.predict(X_test)
predictions = scaler.inverse_transform(predictions)
X_test = scaler.inverse_transform(X_test.reshape(-1, 1))
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
plt.figure(figsize=(12, 6))
plt.plot(actual_prices, label='Actual Prices', color='blue')
plt.plot(predictions, label='Predicted Prices', color='red')
plt.xlabel('Time Steps')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction')
plt.legend()
plt.show()

# %%
# Visualizing Actual vs Predicted Data
plt.figure(figsize=(12, 6))
plt.plot(actual_prices[-20:], label='Actual Prices', color='blue', marker='o')
predicted_future_prices = model.predict(X[-20:])
predicted_future_prices = scaler.inverse_transform(predicted_future_prices)
plt.plot(predicted_future_prices, label='Predicted Prices', color='red', marker='o')
plt.xlabel('Time Steps')
plt.ylabel('Stock Price')
plt.title('Google Stock Price Prediction for Next 20 Days')
plt.legend()
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step

# %% [markdown]
# #### Conclusion
#
# In this analysis, we utilized Long Short-Term Memory (LSTM) networks to predict Google's stock prices. By meticulously preprocessing the data and employing advanced neural network techniques, we developed a model capable of forecasting stock price movements. The visualization of the actual vs. predicted stock prices over the last 20 days demonstrates the model's ability to capture the trends and fluctuations in the market effectively.
#
# The blue markers indicate the actual stock prices, while the red markers represent the predicted prices by our LSTM model. As shown, the predicted prices closely follow the actual prices, indicating a high level of accuracy in our predictions. This alignment underscores the model's robustness and its potential utility in making informed investment decisions.
